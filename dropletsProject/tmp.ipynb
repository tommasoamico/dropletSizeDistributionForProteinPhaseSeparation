# %%
import numpy as np
from functools import reduce

# %%
tmp = [[[20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0]], [[20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0]], [[20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0]], [[20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0]], [[20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0], [20.0, 40.0, 50.0, 60.0, 75.0, 80.0, 100.0]]]


(1/7) * reduce(lambda x, y: np.array(x) + np.array(y), tmp)
# Out:
# array([[14.28571429, 28.57142857, 35.71428571, 42.85714286, 53.57142857,
#         57.14285714, 71.42857143],
#        [14.28571429, 28.57142857, 35.71428571, 42.85714286, 53.57142857,
#         57.14285714, 71.42857143],
#        [14.28571429, 28.57142857, 35.71428571, 42.85714286, 53.57142857,
#         57.14285714, 71.42857143],
#        [14.28571429, 28.57142857, 35.71428571, 42.85714286, 53.57142857,
#         57.14285714, 71.42857143]])

# %%
162 * 0.13
# Out:
# 21.060000000000002
