# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#importing linregress from scipy.stats
from scipy.stats import linregress
from functools import reduce

# %%
fig1DF = pd.read_csv('../Downloads/data_and_figs/FIG1/fig1a.txt')
columnDrop = list(filter(lambda x :'Unnamed' in x, list(fig1DF.columns)))
for column in columnDrop:
    fig1DF = fig1DF.drop(column, axis=1)
x1 = fig1DF.iloc[:,0]
kColumns = list(filter(lambda x :'k' in x, list(fig1DF.columns)))
y1DF = fig1DF[kColumns]
seColumsn = list(filter(lambda x :'SE' in x, list(fig1DF.columns)))
se1DF = fig1DF[seColumsn]

# %%
fig1BDF = pd.read_csv('../Downloads/data_and_figs/FIG1/fig1b.txt', sep = ' ')
fig1BDF

# %%
fig1CDF = pd.read_csv('../Downloads/data_and_figs/FIG1/fig1c.txt')
x1c = fig1CDF.iloc[:,0]
kColumns = list(filter(lambda x :'k' in x, list(fig1CDF.columns)))
y1CDF = fig1CDF[kColumns]
seColumsnC = list(filter(lambda x :'SE' in x, list(fig1CDF.columns)))
se1CDF = fig1CDF[seColumsnC]

# %%
fig1DDF = pd.read_csv('../Downloads/data_and_figs/FIG1/fig1d.txt')
fig1DDF
# Out:
#         1-rho/rhoc  ln(<s>)  SE
# 0  0.020367    4.792508 0.038289
# 1   0.041158    4.572241 0.016773
# 2   0.084083    4.544939 0.007197
# 3  0.175891    4.738576 0.006775
# 4   0.276987    4.881312 0.005111
# 5   0.389465    5.068123 0.005794
# 6   0.516216    5.150686 0.005173
# 7   0.661398    5.186256 0.004507
# 8       Estimate of m with its SE
# 9               1.032159 0.065438

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(9,9* 0.65), tight_layout=True)
plt.rc('font', family='Arial')
fuchsia = '#FFD580'
red = '#E35335'
green = '#40E0D0'
blue = '#0F52BA'
gray = '#36454F'
mediumblue = '#0096FF'
xAxis = np.linspace(0, .7, 100)
cmap = plt.get_cmap('coolwarm')
colors = [cmap(i) for i in np.linspace(0, 1, 4)]
ax1.scatter(x1, y1DF.iloc[:,0], marker='s', color=colors[0], edgecolor = colors[0], s = 100, label = '$k = 0.5$', zorder = 2)
ax1.scatter(x1, y1DF.iloc[:,1], marker='D', color=colors[1], edgecolor = colors[1], s = 100, label = '$k = 1$', zorder = 2)
ax1.scatter(x1, y1DF.iloc[:,2], marker='^', color=colors[2], edgecolor = colors[2], s = 100, label = '$k = 1.5$', zorder = 2)
ax1.scatter(x1, y1DF.iloc[:,3], marker='o', color=colors[3], edgecolor = colors[3], s = 100, label = '$k = 2$', zorder = 2)
ax1.plot(xAxis, xAxis + 4.65, color=colors[3], zorder = 1, linewidth = .7)
ax1.plot(xAxis, xAxis + 4.58, color=colors[2], zorder = 1, linewidth = .7)
ax1.plot(xAxis, xAxis + 4.53, color=colors[1], zorder = 1, linewidth = .7)
ax1.plot(xAxis, xAxis + 4.49, color=colors[0], zorder = 1, linewidth = .7)
ax1.plot(xAxis, xAxis + 4.4, color=gray, zorder = 1, linewidth = 3, label = 'slope = $1$', linestyle = '--')


ax1Inset = ax1.inset_axes([.58, .07, .415, .35])
ax1Inset.errorbar(x1, y1DF.iloc[:,0], yerr = se1DF.iloc[:,0], color = colors[0], zorder = 2, fmt = 'none', capsize = 3)
ax1Inset.errorbar(x1, y1DF.iloc[:,1], yerr = se1DF.iloc[:,1], color = colors[1], zorder = 2, fmt = 'none', capsize = 3)
ax1Inset.errorbar(x1, y1DF.iloc[:,2], yerr = se1DF.iloc[:,2], color = colors[2], zorder = 2, fmt = 'none', capsize = 3)
ax1Inset.errorbar(x1, y1DF.iloc[:,3], yerr = se1DF.iloc[:,3], color = colors[3], zorder = 2, fmt = 'none', capsize = 3)
ax1Inset.plot(xAxis, xAxis + 4.65, color=colors[3], zorder = 1, linewidth = .7)
ax1Inset.plot(xAxis, xAxis + 4.58, color=colors[2], zorder = 1, linewidth = .7)
ax1Inset.plot(xAxis, xAxis + 4.53, color=colors[1], zorder = 1, linewidth = .7)
ax1Inset.plot(xAxis, xAxis + 4.49, color=colors[0], zorder = 1, linewidth = .7)

#ax1.legend(loc = (-.32, .2))
ax1.tick_params(axis='both', which='major', labelsize=17, length=6)
ax1.set_xlim(0, .55)
ax1.set_ylim(4.25, 5.2)
fig.savefig('Fig1A.png', dpi = 300, bbox_inches = 'tight')

# %%
fig, ax3 = plt.subplots(1, 1, figsize=(9,9* 0.65), tight_layout=True)
plt.rc('font', family='Arial')
cmap = plt.get_cmap('coolwarm')
colors = [cmap(i) for i in np.linspace(0, .8, 4)]
ax3.scatter(x1c, y1CDF.iloc[:,0], marker='s', color=colors[0], edgecolor = colors[0], s = 100, label = '$k = 0.5$', zorder = 2)
ax3.scatter(x1c, y1CDF.iloc[:,1], marker='D', color=colors[1], edgecolor = colors[1], s = 100, label = '$k = 1$', zorder = 2)
ax3.scatter(x1c, y1CDF.iloc[:,2], marker='^', color=colors[2], edgecolor = colors[2], s = 100, label = '$k = 1.5$', zorder = 2)
ax3.scatter(x1c, y1CDF.iloc[:,3], marker='o', color=colors[3], edgecolor = colors[3], s = 100, label = '$k = 2$', zorder = 2)
xAxis3 = np.linspace(-.1, .8, 100)
ax3.plot(xAxis3, xAxis + 4.35, color=gray, linestyle = '--', linewidth = 3, label = '$slope = 1$')
ax3.plot(xAxis3, xAxis + 4.85, color=colors[3], zorder = 1, linewidth = .7)
ax3.plot(xAxis3, xAxis + 4.75, color=colors[2], zorder = 1, linewidth = .7)
ax3.plot(xAxis3, xAxis + 4.65, color=colors[1], zorder = 1, linewidth = .7)
ax3.plot(xAxis3, xAxis + 4.59, color=colors[0], zorder = 1, linewidth = .7)


ax3Inset = ax3.inset_axes([.58, .07, .415, .4])
ax3Inset.errorbar(x1c, y1CDF.iloc[:,0], yerr = se1CDF.iloc[:,0], color = colors[0], zorder = 2, fmt = 'none', capsize = 3)
ax3Inset.errorbar(x1c, y1CDF.iloc[:,1], yerr = se1CDF.iloc[:,1], color = colors[1], zorder = 2, fmt = 'none', capsize = 3)
ax3Inset.errorbar(x1c, y1CDF.iloc[:,2], yerr = se1CDF.iloc[:,2], color = colors[2], zorder = 2, fmt = 'none', capsize = 3)
ax3Inset.errorbar(x1c, y1CDF.iloc[:,3], yerr = se1CDF.iloc[:,3], color = colors[3], zorder = 2, fmt = 'none', capsize = 3)
#ax3Inset.plot(xAxis3, xAxis + 4.35, color=gray, linestyle = '--', linewidth = 3, label = '$slope = 1$')
ax3Inset.plot(xAxis3, xAxis + 4.85, color=colors[3], zorder = 1, linewidth = .7)
ax3Inset.plot(xAxis3, xAxis + 4.75, color=colors[2], zorder = 1, linewidth = .7)
ax3Inset.plot(xAxis3, xAxis + 4.65, color=colors[1], zorder = 1, linewidth = .7)
ax3Inset.plot(xAxis3, xAxis + 4.59, color=colors[0], zorder = 1, linewidth = .7)
#ax3.legend(loc = (.5, 1.2))

ax3.tick_params(axis='both', which='major', labelsize=17, length=6)
ax3.set_ylim(4, 5.5)
ax3.set_xlim(0, .7)
fig.savefig('Fig1C.png', dpi = 300, bbox_inches = 'tight')

# %%
xAxis2 = np.linspace(0, .55, 100)
fig, ax2 = plt.subplots(1, 1, figsize=(9,9* 0.65), tight_layout=True)
plt.rc('font', family='Arial')
ax2.scatter(fig1BDF.iloc[:, 0], fig1BDF.iloc[:, 1], zorder = 2, linewidth = .7, s = 200, color = blue)
ax2.plot(xAxis2, xAxis + 4.15, color=gray, linestyle = '--', linewidth = 3, label = '$slope = 1$')
ax2.plot(xAxis2, xAxis + 4.35, color='black', linewidth = .7)
ax2.set_xlim(0, .55)
ax2Inset = ax2.inset_axes([.58, .07, .415, .35])

ax2Inset.errorbar(fig1BDF.iloc[:, 0], fig1BDF.iloc[:, 1], yerr = fig1BDF.iloc[:, 2], zorder = 2, fmt = 'none', capsize = 3, color = blue)
ax2Inset.plot(xAxis2, xAxis + 4.35, color='black', linewidth = .7)
ax2.tick_params(axis='both', which='major', labelsize=17, length=6)
fig.savefig('Fig1B.png', dpi = 300, bbox_inches = 'tight')

# %%
xAxis4 = np.linspace(0, .7, 100)
fig, ax4 = plt.subplots(1, 1, figsize=(9,9* 0.65), tight_layout=True)
ax4Inset = ax4.inset_axes([.58, .07, .415, .35])
ax4.scatter(fig1DDF.iloc[:, 0], fig1DDF.iloc[:, 1], zorder = 2, linewidth = .7, s = 200, color = blue)

ax4.plot(xAxis4, xAxis + 4.38, color=gray, linestyle = '--', linewidth = 3, label = '$slope = 1$')
ax4.plot(xAxis4, xAxis + 4.6, color='black', linewidth = .7)
ax4.set_xlim(0, .7)
#ax4.errorbar(fig1DDF.iloc[:, 0], fig1DDF.iloc[:, 1], yerr = fig1DDF.iloc[:, 2], zorder = 2, fmt = 'none', capsize = 5, color = 'black')


ax4Inset.plot(xAxis4, xAxis + 4.6, color='black', linewidth = .7)
ax4.tick_params(axis='both', which='major', labelsize=17, length=6)
ax4Inset.errorbar(fig1DDF.iloc[:, 0], fig1DDF.iloc[:, 1], yerr = fig1DDF.iloc[:, 2], zorder = 2, fmt = 'none', capsize = 3, color = blue)
fig.savefig('Fig1D.png', dpi = 300, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(2, 2, figsize=(15,int(15* 0.65)), tight_layout=True)
plt.rc('font', family='Arial')
fuchsia = '#FFD580'
red = '#E35335'
green = '#40E0D0'
blue = '#0F52BA'
gray = '#36454F'
mediumblue = '#0096FF'
xAxis = np.linspace(0, .7, 100)
ax1, ax2, ax3, ax4 = ax.flatten()
ax1.scatter(x1, y1DF.iloc[:,0], marker='s', color=red, edgecolor = red, s = 100, label = '$k = 0.5$', zorder = 2)
ax1.scatter(x1, y1DF.iloc[:,1], marker='D', color=green, edgecolor = green, s = 100, label = '$k = 1$', zorder = 2)
ax1.scatter(x1, y1DF.iloc[:,2], marker='^', color=blue, edgecolor = blue, s = 100, label = '$k = 1.5$', zorder = 2)
ax1.scatter(x1, y1DF.iloc[:,3], marker='o', color=fuchsia, edgecolor = fuchsia, s = 100, label = '$k = 1.5$', zorder = 2)
ax1.plot(xAxis, xAxis + 4.35, color=gray, linestyle = '--', linewidth = 3, label = '$slope = 1$')
ax1.plot(xAxis, xAxis + 4.65, color=fuchsia, zorder = 1, linewidth = .7)
ax1.plot(xAxis, xAxis + 4.58, color=blue, zorder = 1, linewidth = .7)
ax1.plot(xAxis, xAxis + 4.53, color=green, zorder = 1, linewidth = .7)
ax1.plot(xAxis, xAxis + 4.49, color=red, zorder = 1, linewidth = .7)


ax1Inset = ax1.inset_axes([.58, .07, .415, .35])
ax1Inset.errorbar(x1, y1DF.iloc[:,0], yerr = se1DF.iloc[:,0], color = red, zorder = 2, fmt = 'none', capsize = 3)
ax1Inset.errorbar(x1, y1DF.iloc[:,1], yerr = se1DF.iloc[:,1], color = green, zorder = 2, fmt = 'none', capsize = 3)
ax1Inset.errorbar(x1, y1DF.iloc[:,2], yerr = se1DF.iloc[:,2], color = blue, zorder = 2, fmt = 'none', capsize = 3)
ax1Inset.errorbar(x1, y1DF.iloc[:,3], yerr = se1DF.iloc[:,3], color = fuchsia, zorder = 2, fmt = 'none', capsize = 3)
ax1Inset.plot(xAxis, xAxis + 4.65, color=fuchsia, zorder = 1, linewidth = .7)
ax1Inset.plot(xAxis, xAxis + 4.58, color=blue, zorder = 1, linewidth = .7)
ax1Inset.plot(xAxis, xAxis + 4.53, color=green, zorder = 1, linewidth = .7)
ax1Inset.plot(xAxis, xAxis + 4.49, color=red, zorder = 1, linewidth = .7)

xAxis2 = np.linspace(0, .55, 100)
ax2.scatter(fig1BDF.iloc[:, 0], fig1BDF.iloc[:, 1], zorder = 2, linewidth = .7, s = 200, color = mediumblue)
ax2.plot(xAxis2, xAxis + 4.15, color=gray, linestyle = '--', linewidth = 3, label = '$slope = 1$')
ax2.plot(xAxis2, xAxis + 4.35, color='black', linewidth = .7)
ax2.set_xlim(0, .55)
ax2Inset = ax2.inset_axes([.58, .07, .415, .35])
ax2Inset.errorbar(fig1BDF.iloc[:, 0], fig1BDF.iloc[:, 1], yerr = fig1BDF.iloc[:, 2], zorder = 2, fmt = 'none', capsize = 3, color = mediumblue)
ax2Inset.plot(xAxis2, xAxis + 4.35, color='black', linewidth = .7)

ax3.scatter(x1c, y1CDF.iloc[:,0], marker='s', color=red, edgecolor = red, s = 100, label = '$k = 0.5$', zorder = 2)
ax3.scatter(x1c, y1CDF.iloc[:,1], marker='D', color=green, edgecolor = green, s = 100, label = '$k = 1$', zorder = 2)
ax3.scatter(x1c, y1CDF.iloc[:,2], marker='^', color=blue, edgecolor = blue, s = 100, label = '$k = 1.5$', zorder = 2)
ax3.scatter(x1c, y1CDF.iloc[:,3], marker='o', color=fuchsia, edgecolor = fuchsia, s = 100, label = '$k = 1.5$', zorder = 2)
xAxis3 = np.linspace(-.1, .8, 100)
ax3.plot(xAxis3, xAxis + 4.35, color=gray, linestyle = '--', linewidth = 3, label = '$slope = 1$')
ax3.plot(xAxis3, xAxis + 4.85, color=fuchsia, zorder = 1, linewidth = .7)
ax3.plot(xAxis3, xAxis + 4.75, color=blue, zorder = 1, linewidth = .7)
ax3.plot(xAxis3, xAxis + 4.65, color=green, zorder = 1, linewidth = .7)
ax3.plot(xAxis3, xAxis + 4.59, color=red, zorder = 1, linewidth = .7)


ax3Inset = ax3.inset_axes([.58, .07, .415, .4])
ax3Inset.errorbar(x1c, y1CDF.iloc[:,0], yerr = se1CDF.iloc[:,0], color = red, zorder = 2, fmt = 'none', capsize = 3)
ax3Inset.errorbar(x1c, y1CDF.iloc[:,1], yerr = se1CDF.iloc[:,1], color = green, zorder = 2, fmt = 'none', capsize = 3)
ax3Inset.errorbar(x1c, y1CDF.iloc[:,2], yerr = se1CDF.iloc[:,2], color = blue, zorder = 2, fmt = 'none', capsize = 3)
ax3Inset.errorbar(x1c, y1CDF.iloc[:,3], yerr = se1CDF.iloc[:,3], color = fuchsia, zorder = 2, fmt = 'none', capsize = 3)
#ax3Inset.plot(xAxis3, xAxis + 4.35, color=gray, linestyle = '--', linewidth = 3, label = '$slope = 1$')
ax3Inset.plot(xAxis3, xAxis + 4.85, color=fuchsia, zorder = 1, linewidth = .7)
ax3Inset.plot(xAxis3, xAxis + 4.75, color=blue, zorder = 1, linewidth = .7)
ax3Inset.plot(xAxis3, xAxis + 4.65, color=green, zorder = 1, linewidth = .7)
ax3Inset.plot(xAxis3, xAxis + 4.59, color=red, zorder = 1, linewidth = .7)


ax3.set_ylim(4, 5.5)
ax3.set_xlim(0, .7)

xAxis4 = np.linspace(0, .7, 100)
ax4Inset = ax4.inset_axes([.58, .07, .415, .35])
ax4.scatter(fig1DDF.iloc[:, 0], fig1DDF.iloc[:, 1], zorder = 2, linewidth = .7, s = 200, color = mediumblue)

ax4.plot(xAxis4, xAxis + 4.38, color=gray, linestyle = '--', linewidth = 3, label = '$slope = 1$')
ax4.plot(xAxis4, xAxis + 4.6, color='black', linewidth = .7)
ax4.set_xlim(0, .7)
#ax4.errorbar(fig1DDF.iloc[:, 0], fig1DDF.iloc[:, 1], yerr = fig1DDF.iloc[:, 2], zorder = 2, fmt = 'none', capsize = 5, color = 'black')


ax4Inset.plot(xAxis4, xAxis + 4.6, color='black', linewidth = .7)

ax4Inset.errorbar(fig1DDF.iloc[:, 0], fig1DDF.iloc[:, 1], yerr = fig1DDF.iloc[:, 2], zorder = 2, fmt = 'none', capsize = 3, color = mediumblue)
for ax_ in ax.flatten():
    ax_.tick_params(axis='both', which='major', labelsize=17, length=6)
#ax1Inset.scatter(x1, y1DF.iloc[:,1], marker='D', color='white', edgecolor = 'lime', s = 100, label = '$k = 1$', zorder = 2)
#ax1Inset.scatter(x1, y1DF.iloc[:,2], marker='^', color='white', edgecolor = 'blue', s = 100, label = '$k = 1.5$', zorder = 2)
#ax1Inset.scatter(x1, y1DF.iloc[:,3], marker='X', color='white', edgecolor = 'fuchsia', s = 100, label = '$k = 1.5$', zorder = 2)
ax1.legend(loc = (-.32, -.2))
ax1.set_xlim(0, .55)
ax1.set_ylim(4.25, 5.2)
fig.savefig('Fig1.png', dpi = 300, bbox_inches = 'tight')

# %%
fig2A1 = pd.read_csv('../Downloads/data_and_figs/FIG2/fig2a1.txt', sep = ' ', header = None)
fig2A1 = fig2A1.iloc[:, :-1]
fig2A1Conc = [0.125, 0.25, 0.5, 1, 2]
columns = []
for conc in fig2A1Conc:
    columns += [f'x_{conc}', f'y_{conc}', f'se_{conc}']
fig2A1.columns = columns
fig2A1.head()

# %%
fig2A2 = pd.read_csv('../Downloads/data_and_figs/FIG2/fig2a2.txt', sep = ' ', header = None)
fig2A2 = fig2A2.iloc[:, :-1]
fig2A2Conc = [0.125, 0.25, 0.5, 1, 1.5, 2, 2.5, 3]
columns = []
for conc in fig2A2Conc:
    columns += [f'x_{conc}', f'y_{conc}', f'se_{conc}']
fig2A2.columns = columns
fig2A2.head()

# %%
def f(x):
    return np.exp(-(x**2)/2)/np.sqrt(2*np.pi)

# %%
fig2ApappuA = pd.read_csv('../Downloads/data_and_figs/FIG2/pappu_a.csv')
fig2ApappuA.head()
# Out:
#    Size     0.125_mean      0.125_std     0.25_mean      0.25_std  \
# 0     5       0.000000       0.000000  0.000000e+00  0.000000e+00
# 1    15   75353.000000  106565.234565  1.475533e+04  2.086719e+04
# 2    25  461733.000000  396471.508008  5.723317e+05  6.413987e+04
# 3    35  758446.666667  511771.523338  2.243823e+06  1.096733e+05
# 4    45  978349.333333  348981.632871  6.820681e+06  1.032753e+06
#
#        0.5_mean       0.5_std        1_mean          1_std        2_mean  \
# 0  0.000000e+00  0.000000e+00  0.000000e+00       0.000000  0.000000e+00
# 1  4.391967e+04  3.712578e+04  0.000000e+00       0.000000  0.000000e+00
# 2  7.543807e+05  2.032875e+05  5.563967e+04   20508.874410  5.246007e+05
# 3  3.194082e+06  6.594776e+05  1.102828e+06  286673.163652  1.977989e+06
# 4  9.870287e+06  1.420919e+06  3.594954e+06  444809.082494  6.112318e+06
#
#           2_std
# 0  0.000000e+00
# 1  0.000000e+00
# 2  2.877458e+05
# 3  5.296509e+05
# 4  1.270441e+06

# %%
fig, ax = plt.subplots(1, 1, figsize=(int(12* 0.95), 12), tight_layout=True)
cmap = plt.get_cmap('coolwarm')
colors = [cmap(x) for x in np.linspace(0, .4, 5)]
markers1 = ['o', 'D', '^', '>', 's']
cmap2 = plt.get_cmap('coolwarm')
colors2 = [cmap2(x) for x in np.linspace(0.5, 1, len(fig2A2Conc))]
markers2 = ['^', 'h', 'd', 'o', 'D', 'p', '8', 'v']
xColumns = [x for x in fig2A1.columns if 'x' in x]
x2Columns = [x for x in fig2A2.columns if 'x' in x]
xDf = fig2A1[xColumns]
xDf2 = fig2A2[x2Columns]
yColumns = [x for x in fig2A1.columns if 'y' in x]
y2Columns = [x for x in fig2A2.columns if 'y' in x]
yDf2 = fig2A2[y2Columns]
yDf = fig2A1[yColumns]
seColumns = [x for x in fig2A1.columns if 'se' in x]
se2Columns = [x for x in fig2A2.columns if 'se' in x]
seDf = fig2A1[seColumns]
seDf2 = fig2A2[se2Columns]


fig4A = pd.read_csv('../Downloads/data_and_figs/FIG4/fig4a.txt', sep = ' ')
fig4A = fig4A.iloc[:,:-1]
seColumns = [x for x in fig4A.columns if 'SE' in x]
seDf4A = fig4A[seColumns]
seDf4A /= np.sqrt(3)

ax.tick_params(axis='both', which='major', labelsize=17, length=6)
xAxis = np.linspace(-4, 4, 1000)
ax.plot(xAxis, f(xAxis), color=gray, linewidth = 5, zorder = 5, label = '$\\dfrac{e^{-\\frac{x^2}{2}}}{\sqrt{(2 \pi)}}$', linestyle = '--')
for i in range(1, len(xColumns)):
    ax.scatter(xDf.iloc[:,i], yDf.iloc[:,i], marker = markers1[i], s = 100, color = colors[i], label = f'FUS, $\\rho = {fig2A1Conc[i]:.3f}$')
    ax.plot(xDf.iloc[:,i], yDf.iloc[:,i], color = colors[i])
    ax.errorbar(xDf.iloc[:,i], yDf.iloc[:,i], yerr = seDf4A.iloc[:,i], zorder = 2, fmt = 'none', capsize = 5, color = colors[i])

fig4C = pd.read_csv('../Downloads/data_and_figs/FIG4/fig4c.txt', sep = ' ')
fig4C = fig4C.iloc[:,:-1]

seColumns4C = [x for x in fig4C.columns if 'SE' in x]
seDf4C = fig4C[seColumns4C]
seDf4C /= np.sqrt(3)

for j in range(2, len(x2Columns)):
    ax.scatter(xDf2.iloc[:,j], yDf2.iloc[:,j], marker = markers2[j], s = 100, color = colors2[j], label = f'SNAP FUS, $\\rho = {fig2A2Conc[j]:.3f}$')
    ax.plot(xDf2.iloc[:,j], yDf2.iloc[:,j], color = colors2[j])
    ax.errorbar(xDf2.iloc[:,j], yDf2.iloc[:,j], yerr = seDf4C.iloc[:,j], zorder = 2, fmt = 'none', capsize = 5, color = colors2[j])
ax.legend(loc = (1.1, .5))
ax.set_xlim(-4, 4)
#fig.savefig('Fig2A.png', dpi = 300, bbox_inches = 'tight')
fig.savefig('Fig2ABis.png', dpi = 300, bbox_inches = 'tight')

# %%
fig2BCFUS = pd.read_csv('../Downloads/data_and_figs/FIG2/fig2b.txt', sep = ' ')
fig2BCSNAP = pd.read_csv('../Downloads/data_and_figs/FIG2/fig2c.txt', sep = ' ')
fig2BCFUS.head()
# Out:
#    rho(μM)      s0(nm)        SE     sigma      SE.1
# 0    0.125   82.203177  3.075130  0.207730  0.028021
# 1    0.250   80.542412  0.928143  0.131018  0.007364
# 2    0.500   85.749908  0.657713  0.100124  0.003018
# 3    1.000  101.427148  0.644062  0.094726  0.002460
# 4    2.000  127.257339  0.785076  0.130525  0.003308

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 0.65 * 9), tight_layout=True)

cmap = plt.get_cmap('coolwarm')
colr1, color2 = cmap(0.1), cmap(0.9)
axInset = ax.inset_axes([.50, .05, .49, .4])
ax.scatter(fig2BCFUS['rho(μM)'], fig2BCFUS['s0(nm)'], s = 200, color = blue, label = 'FUS')
axInset.errorbar(fig2BCFUS['rho(μM)'], fig2BCFUS['s0(nm)'], yerr = fig2BCFUS['SE'], zorder = 2, fmt = 'none', capsize =3, color = blue)
ax.scatter(fig2BCSNAP['rho(μM)'], fig2BCSNAP['s0(nm)'], s = 200, color = color2, label = 'SNAP FUS')
axInset.errorbar(fig2BCSNAP['rho(μM)'], fig2BCSNAP['s0(nm)'], yerr = fig2BCSNAP['SE'], zorder = 2, fmt = 'none', capsize = 3, color = color2)
ax.tick_params(axis='both', which='major', labelsize=17, length=6)
#ax.legend(loc=(1.01, .5))
fig.savefig('Fig2B.png', dpi = 300, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 0.65 * 9), tight_layout=True)
cmap = plt.get_cmap('coolwarm')
colr1, color2 = cmap(0.1), cmap(0.9)
ax.scatter(fig2BCFUS['rho(μM)'], fig2BCFUS['sigma'], s = 200, color = blue, label = 'FUS')
axInset = ax.inset_axes([.50, .58, .49, .4])
axInset.errorbar(fig2BCFUS['rho(μM)'], fig2BCFUS['sigma'], yerr = fig2BCFUS['SE.1'], zorder = 2, fmt = 'none', capsize =3, color = blue)
ax.scatter(fig2BCSNAP['rho(μM)'], fig2BCSNAP['sigma'], s = 200, color = color2, label = 'SNAP FUS')
axInset.errorbar(fig2BCSNAP['rho(μM)'], fig2BCSNAP['sigma'], yerr = fig2BCSNAP['SE.1'], zorder = 2, fmt = 'none', capsize = 3, color = color2)
ax.tick_params(axis='both', which='major', labelsize=17, length=6)
ax.set_ylim(0.05, 0.3)
fig.savefig('Fig2C.png', dpi = 300, bbox_inches = 'tight')

# %%
fig3A = pd.read_csv('../Downloads/data_and_figs/FIG3/fig3a.txt', sep = ' ')
x3a = fig3A.iloc[:,0]
kColumns = [x for x in fig3A.columns if 'k' in x]
kDf = fig3A[kColumns]
se3Columns = [x for x in fig3A.columns if 'SE' in x]
se3Df = fig3A[se3Columns]

# %%
import matplotlib.colors as colors
cmapBlue = plt.get_cmap('Blues')
cmapBlue = [cmapBlue(i) for i in np.linspace(0.2, 1, 128)]
cmapBlue = colors.LinearSegmentedColormap.from_list(name = 'myCmap', colors = cmapBlue)
cmapRed = plt.get_cmap('Reds')
cmapRed = [cmapRed(i) for i in np.linspace(0.2, 1, 128)]
cmapRed = colors.LinearSegmentedColormap.from_list(name = 'myCmap', colors = cmapRed)
cmapPurple = plt.get_cmap('Purples')
cmapPurple = [cmapPurple(i) for i in np.linspace(0.2, 1, 128)]
cmapPurple = colors.LinearSegmentedColormap.from_list(name = 'myCmap', colors = cmapPurple)
cmapGreen = plt.get_cmap('Greens')
cmapGreen = [cmapGreen(i) for i in np.linspace(0.2, 1, 128)]
cmapGreen = colors.LinearSegmentedColormap.from_list(name = 'myCmap', colors = cmapGreen)
cmapOrange = plt.get_cmap('Oranges')
cmapOrange = [cmapOrange(i) for i in np.linspace(0.2, 1, 128)]
cmapOrange = colors.LinearSegmentedColormap.from_list(name = 'myCmap', colors = cmapOrange)
cmapGray = plt.get_cmap('Greys')
cmapGray = [cmapGray(i) for i in np.linspace(0.2, 1, 128)]
cmapGray = colors.LinearSegmentedColormap.from_list(name = 'myCmap', colors = cmapGray)

# %%
fig3ALines = pd.read_csv('../Downloads/data_and_figs/FIG3/fig3aLines.txt', sep = ' ')

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 0.65 * 9), tight_layout=True)
ax.tick_params(axis='both', which='major', labelsize=17, length=6)
fuchsia = 'forestgreen'
red = '#E35335'
green = '#40E0D0'
blue = '#0F52BA'
gray = '#36454F'
pink = '#DC143C'
purple = '#663399'
kValues = [x.split('=')[1] for x in kColumns]
markers = ['o', 's', 'D', 'v', '>', '<']
colors = [fuchsia, red, green, blue, gray, pink, purple]
xAxis = np.linspace(0, 5.2, 100)
cmap = plt.get_cmap('coolwarm')
colors = cmap(np.linspace(0, 1, len(kColumns)))
for i in range(len(kColumns)):
    ax.scatter(x3a, kDf.iloc[:,i], s = 140, color = colors[i], label = f'$k = {kValues[i]}$',\
                zorder = 3, linewidth = .7, marker = markers[i])
    slope, intercept, r_value, p_value, std_err = linregress(x3a[2:], kDf.iloc[2:,i])
    ax.plot(xAxis, fig3ALines['slope'][i] * xAxis + fig3ALines['intercept'][i], color = colors[i], zorder = 2)
    #ax.errorbar(x3a, kDf.iloc[:,i], yerr = se3Df.iloc[:,i], zorder = 2, fmt = 'none', capsize = 5, color = colors[i])
axInset = ax.inset_axes([.50, .58, .49, .4])
for i in range(len(kColumns)):
    axInset.errorbar(x3a, kDf.iloc[:,i], yerr = se3Df.iloc[:,i], zorder = 2, fmt = 'none', capsize = 3, color = colors[i])
ax.scatter(5.117434, 0, s = 100, color = '#FFD700', label = '$ \\rho_c$ estimate', zorder = 5)
se = 0.148100
ax.errorbar(5.117434, 0, xerr=se, color = '#FFD700', linewidth = 3, capsize = 5, capthick = 3)
ax.set_ylim(bottom = 0)
#ax.legend(loc = (1.05, .5), markerscale = .6)
fig.savefig('Fig3A.png', dpi = 300, bbox_inches = 'tight')

# %%
fig3B = pd.read_csv('../Downloads/data_and_figs/FIG3/fig3b.txt', sep = ' ')
x3b = fig3B.iloc[:,0]
kColumns = [x for x in fig3B.columns if 'k' in x]
kDf = fig3B[kColumns]
se3Columns = [x for x in fig3B.columns if 'SE' in x]
se3Df = fig3B[se3Columns]
fig3BLines = pd.read_csv('../Downloads/data_and_figs/FIG3/fig3bLines.txt', sep = ' ')

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 0.5 * 9), tight_layout=True)
ax.tick_params(axis='both', which='major', labelsize=17, length=6)
fuchsia = 'forestgreen'
red = '#E35335'
green = '#40E0D0'
blue = '#0F52BA'
gray = '#36454F'
pink = '#DC143C'
purple = '#663399'
kValues = [x.split('=')[1] for x in kColumns]
markers = ['o', 's', 'D', 'v', '>', '<']
colors = [fuchsia, red, green, blue, gray, pink, purple]
xAxis = np.linspace(0, 6.25, 100)
cmap = plt.get_cmap('coolwarm')
colors = cmap(np.linspace(0, 1, len(kColumns)))
for i in range(len(kColumns)):
    ax.scatter(x3b[1:], kDf.iloc[:,i][1:], s = 140, color = colors[i], label = f'$k = {kValues[i]}$',\
                zorder = 3, linewidth = .7, marker = markers[i])
    slope, intercept, r_value, p_value, std_err = linregress(x3b[2:], kDf.iloc[2:,i])
    ax.plot(xAxis, fig3BLines['slope'][i] * xAxis + fig3BLines['intercept'][i], color = colors[i], zorder = 2)
    #ax.errorbar(x3a, kDf.iloc[:,i], yerr = se3Df.iloc[:,i], zorder = 2, fmt = 'none', capsize = 5, color = colors[i])
axInset = ax.inset_axes([.50, .58, .49, .4])
for i in range(len(kColumns)):
    axInset.errorbar(x3b, kDf.iloc[:,i], yerr = se3Df.iloc[:,i], zorder = 2, fmt = 'none', capsize = 3, color = colors[i])
ax.scatter(6.24336, 0, s = 100, color = '#FFD700', label = '$ \\rho_c$ estimate', zorder = 5)
se = 0.3036205985463594
 
ax.errorbar(6.24336, 0, xerr=se, color = '#FFD700', linewidth = 3, capsize = 5, capthick = 3)
ax.set_ylim(bottom = 0)
#ax.legend(loc = (1.05, .5), markerscale = .6)
fig.savefig('Fig3BWider.png', dpi = 300, bbox_inches = 'tight')

# %%
fig4A = pd.read_csv('../Downloads/data_and_figs/FIG4/fig4a.txt', sep = ' ')
fig4A = fig4A.iloc[:,:-1]
x = fig4A.iloc[:,0]
yColumns = [x for x in fig4A.columns if 'P' in x]
seColumns = [x for x in fig4A.columns if 'SE' in x]
yDf = fig4A[yColumns]
seDf = fig4A[seColumns]
fig, ax = plt.subplots(1, 1, figsize=(9, 0.65 * 9), tight_layout=True)
ax.tick_params(axis='both', which='major', labelsize=17, length=6)
concFus = [0.125, 0.25, 0.5, 1, 2]
cmap = plt.get_cmap('coolwarm')
colors = cmap(np.linspace(0, 1, len(concFus)))
for i in range(len(concFus)):
    ax.plot(x, yDf.iloc[:,i], color = colors[i], label = f'$\\rho = {concFus[i]:.3f}$', linewidth = 3)
    ax.errorbar(x, yDf.iloc[:,i], yerr = seDf.iloc[:,i]/np.sqrt(3), zorder = 2, fmt = 'none', capsize = 5, color = colors[i])
#ax.legend(loc = (1.05, .5))
fig.savefig('Fig4A.png', dpi = 300, bbox_inches = 'tight')

# %%
fig4B = pd.read_csv('../Downloads/data_and_figs/FIG4/fig4b.txt', sep = ' ', header = None)
fig4B = fig4B.iloc[:,:-1]
colors = cmap(np.linspace(0, 1, len(concFus)))
columns = [[f'x_{i}', f'y_{i}', f'se_{i}'] for i in range(1, 6)]
columns = list(reduce(lambda x, y: x + y, columns))
fig4B.columns = columns
concFus = [0.125, 0.25, 0.5, 1, 2]
fig, ax = plt.subplots(1, 1, figsize=(9, 0.65 * 9), tight_layout=True)
ax.tick_params(axis='both', which='major', labelsize=17, length=6)
for i in range(len(concFus)):
    ax.plot(fig4B.iloc[:,3*i], fig4B.iloc[:,3*i+1], color = colors[i], label = f'$\\rho = {concFus[i]:.3f}$', linewidth = 3)
    ax.errorbar(fig4B.iloc[:,3*i], fig4B.iloc[:,3*i+1], yerr = fig4B.iloc[:,3*i+2]/np.sqrt(3), zorder = 2, fmt = 'none', capsize = 5, color = colors[i])

fig4BLog = pd.read_csv('../Downloads/data_and_figs/FIG4/fig4bLog.txt', sep = ' ', header = None)
ax.plot(fig4BLog.iloc[:,0], fig4BLog.iloc[:,1], color = gray, label = 'Lognormal', linewidth = 3, linestyle = '--')
ax.set_xlim(0, 200)
#ax.legend(loc = (1.05, .5))
fig.savefig('Fig4B.png', dpi = 300, bbox_inches = 'tight')

# %%
fig4C = pd.read_csv('../Downloads/data_and_figs/FIG4/fig4c.txt', sep = ' ')
fig4C = fig4C.iloc[:,:-1]


x = fig4C.iloc[:,0]
yColumns = [x for x in fig4C.columns if 'P' in x]
seColumns = [x for x in fig4C.columns if 'SE' in x]
yDf = fig4C[yColumns]
seDf = fig4C[seColumns]
fig, ax = plt.subplots(1, 1, figsize=(9, 0.65 * 9), tight_layout=True)
ax.tick_params(axis='both', which='major', labelsize=17, length=6)
SnapConcFus = [0.125, 0.25, 0.5, 1, 1.5, 2, 2.5, 3]
cmap = plt.get_cmap('coolwarm')
colors = cmap(np.linspace(0, 1, len(SnapConcFus)))
for i in range(len(SnapConcFus)):
    ax.plot(x, yDf.iloc[:,i], color = colors[i], label = f'$\\rho = {SnapConcFus[i]:.3f}$', linewidth = 3)
    ax.errorbar(x, yDf.iloc[:,i], yerr = seDf.iloc[:,i]/np.sqrt(3), zorder = 2, fmt = 'none', capsize = 5, color = colors[i])
#ax.legend(loc = (1.05, .5))
ax.set_xlim(0, 300)
fig.savefig('Fig4C.png', dpi = 300, bbox_inches = 'tight')

# %%
fig4D = pd.read_csv('../Downloads/data_and_figs/FIG4/fig4d.txt', sep = ' ', header = None)
fig4D = fig4D.iloc[:,:-1]
colors = cmap(np.linspace(0, 1, len(SnapConcFus)))
columns = [[f'x_{i}', f'y_{i}', f'se_{i}'] for i in range(1, len(SnapConcFus) + 1)]
columns = list(reduce(lambda x, y: x + y, columns))
fig4D.columns = columns
fig, ax = plt.subplots(1, 1, figsize=(9, 0.65 * 9), tight_layout=True)
for i in range(len(SnapConcFus)):
    ax.plot(fig4D.iloc[:,3*i], fig4D.iloc[:,3*i+1], color = colors[i], label = f'$\\rho = {SnapConcFus[i]:.3f}$', linewidth = 3)
    ax.errorbar(fig4D.iloc[:,3*i], fig4D.iloc[:,3*i+1], yerr = fig4D.iloc[:,3*i+2]/np.sqrt(3), zorder = 2, fmt = 'none', capsize = 5, color = colors[i])
ax.tick_params(axis='both', which='major', labelsize=17, length=6)
fig4BLog = pd.read_csv('../Downloads/data_and_figs/FIG4/fig4dLog.txt', sep = ' ', header = None)
ax.plot(fig4BLog.iloc[:,0], fig4BLog.iloc[:,1], color = gray, label = 'Lognormal', linewidth = 3, linestyle = '--', zorder = 4)
ax.set_xlim(0, 200)
#ax.legend(loc = (1.05, .5))
fig.savefig('Fig4D.png', dpi = 300, bbox_inches = 'tight')
